# %%
# %load_ext cython

# %%
# %%cython -a
#
# import numpy as np
# import itertools as it
# from scipy.special import gamma
# from scipy.special import multigammaln
# import cython
# cimport numpy as np
# from numpy.math cimport INFINITY
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def BHC_vanilla(data, likelihood, int alpha):
#     """
#     Bayesian hierarchical clustering algorithm, direct implementation from paper.
#
#     Parameters
#     ----------
#     data : 2D numpy array
#         Data with rows as observations and columns as variables.
#     likelihood : function
#         Function that returns the marginal likelihood of data in BHC model.
#     alpha : float
#         Concentration parameter in model.
#
#     Returns
#     -------
#     T_record : list(list(int))
#         Cluster structure in each iteration.
#     rk_record : list(float)
#         Merge probability (rk) in each iteration.
#     """
#
#     #Using Cython
#
#     cdef int i, j
#     cdef float max_rk
#     cdef int left_merge, right_merge
#
#     cdef double rk, dk, pi_k
#     cdef double likelihood_i, likelihood_j, likelihood_k
#
#     cdef int n = data.shape[0]
#     cdef int p = data.shape[1]
#     cdef int c = n
#     D = dict((index, Node(obs.reshape(-1, p), alpha)) for index, obs in enumerate(data))
#     T = list(range(n))
#     T_record = list(T)
#     rk_record = [1]
#
#     while c > 1:
#
#         max_rk = -INFINITY
#         node_merge = None
#         left_merge = -1
#         right_merge = -1
#
#         for i, j in it.combinations(D.keys(), 2):
#             Di = D[i]
#             Dj = D[j]
#             Dk = Node.merge_node(Di, Dj)
#
#             likelihood_i = likelihood(Di.data)
#             likelihood_j = likelihood(Dj.data)
#             likelihood_k = likelihood(Dk.data)
#
#             pi_k = Dk.pi_k
#
#             rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)
#
#             if rk > max_rk:
#                 max_rk = rk
#                 node_merge = Dk
#                 left_merge = i
#                 right_merge = j
#
#         #delete merged nodes and store new node
#         del D[right_merge]
#         D[left_merge] = node_merge
#
#         #store the current tree structure and value of rk
#         for item_index, node_index in enumerate(T):
#             if node_index == right_merge:
#                 T[item_index] = left_merge
#         T_record.append(list(T))
#         rk_record.append(max_rk)
#
#         c -= 1
#
#     return T_record, rk_record
#
#
# class Node(object):
#     """
#     Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.
#
#     Attributes
#     ----------
#     data : 2D numpy array
#         Data with rows as observations and columns as variables.
#     dk : float
#         Some kind of number for computing probabilities
#     pi_k : float
#         For to compute merge probability
#
#     Methods
#     -------
#     __init__(self, data, likelihood, alpha = 1)
#         Instantiation operation.
#     merge_node(cls, node1, node2, alpha = 1)
#         Method that merges two Nodes into one new Node and return the new Node.
#     """
#
#     def __init__(self, np.ndarray[dtype = double, ndim = 2] data, int alpha = 1, double dk = 1, double pi_k = 1):
#         """
#         Instantiation operation.
#
#         Parameters
#         ----------
#         data : 2D numpy array
#             Data with rows as observations and columns as variables.
#         likelihood : function
#             Function that returns the likelihood of data, sampling distribution in BHC model.
#         alpha : float
#             Concentration parameter in model.
#         log_dk : float
#             Cached probability variable. Do not define if the node is a leaf.
#         log_pi : float
#             Cached probability variable. Do not define if the node is a leaf.
#         """
#
#         #initialized according to paper
#         self.data = data
#         self.dk = dk
#         self.pi_k = pi_k
#
#     @classmethod
#     def merge_node(cls, node1, node2, int alpha = 1):
#         """
#         Merge two Nodes into one new Node and return the new Node.
#
#         Parameters
#         ----------
#         node1 : Node
#             First Node.
#         node2 : Node
#             Second Node.
#         """
#
#         cdef np.ndarray[dtype = double, ndim = 2] data = np.vstack((node1.data, node2.data))
#
#         cdef int nk = data.shape[0]
#         dk = alpha * gamma(nk) + node1.dk * node2.dk
#         pi_k = alpha * gamma(nk) / dk
#
#         return cls(data, alpha, dk, pi_k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2e482b265728> in <module>()
# ----> 1 get_ipython().run_cell_magic('cython', '-a', '\nimport numpy as np\nimport itertools as it\nfrom scipy.special import gamma\nfrom scipy.special import multigammaln\nimport cython\ncimport numpy as np\nfrom numpy.math cimport INFINITY\n\n@cython.boundscheck(False)\n@cython.wraparound(False)\ndef BHC_vanilla(data, likelihood, int alpha):\n    """\n    Bayesian hierarchical clustering algorithm, direct implementation from paper.\n    \n    Parameters\n    ----------\n    data : 2D numpy array\n        Data with rows as observations and columns as variables.\n    likelihood : function\n        Function that returns the marginal likelihood of data in BHC model.\n    alpha : float\n        Concentration parameter in model.\n        \n    Returns\n    -------\n    T_record : list(list(int))\n        Cluster structure in each iteration.\n    rk_record : list(float)\n        Merge probability (rk) in each iteration.\n    """\n    \n    #Using Cython \n\n    cdef int i, j\n    cdef float max_rk\n    cdef int left_merge, right_merge\n    \n    cdef double rk, dk, pi_k\n    cdef double likelihood_i, likelihood_j, likelihood_k\n    \n    cdef int n = data.shape[0]\n    cdef int p = data.shape[1]\n    cdef int c = n\n    D = dict((index, Node(obs.reshape(-1, p), alpha)) for index, obs in enumerate(data))\n    T = list(range(n))\n    T_record = list(T)\n    rk_record = [1]\n    \n    while c > 1:\n        \n        max_rk = -INFINITY\n        node_merge = None\n        left_merge = -1\n        right_merge = -1\n        \n        for i, j in it.combinations(D.keys(), 2):\n            Di = D[i]\n            Dj = D[j]\n            Dk = Node.merge_node(Di, Dj)\n            \n            likelihood_i = likelihood(Di.data)\n            likelihood_j = likelihood(Dj.data)\n            likelihood_k = likelihood(Dk.data)\n            \n            pi_k = Dk.pi_k\n\n            rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)\n\n            if rk > max_rk:\n                max_rk = rk\n                node_merge = Dk\n                left_merge = i\n                right_merge = j\n        \n        #delete merged nodes and store new node\n        del D[right_merge]\n        D[left_merge] = node_merge\n\n        #store the current tree structure and value of rk\n        for item_index, node_index in enumerate(T):\n            if node_index == right_merge:\n                T[item_index] = left_merge\n        T_record.append(list(T))\n        rk_record.append(max_rk)\n        \n        c -= 1\n        \n    return T_record, rk_record\n        \n\nclass Node(object):\n    """\n    Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.\n    \n    Attributes\n    ----------\n    data : 2D numpy array\n        Data with rows as observations and columns as variables.\n    dk : float\n        Some kind of number for computing probabilities\n    pi_k : float\n        For to compute merge probability\n        \n    Methods\n    -------\n    __init__(self, data, likelihood, alpha = 1)\n        Instantiation operation.\n    merge_node(cls, node1, node2, alpha = 1)\n        Method that merges two Nodes into one new Node and return the new Node.\n    """\n    \n    def __init__(self, np.ndarray[dtype = double, ndim = 2] data, int alpha = 1, double dk = 1, double pi_k = 1):\n        """\n        Instantiation operation.\n        \n        Parameters\n        ----------\n        data : 2D numpy array\n            Data with rows as observations and columns as variables.\n        likelihood : function\n            Function that returns the likelihood of data, sampling distribution in BHC model.\n        alpha : float\n            Concentration parameter in model.\n        log_dk : float\n            Cached probability variable. Do not define if the node is a leaf.\n        log_pi : float\n            Cached probability variable. Do not define if the ...
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-125> in cython(self, line, cell)
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\erics\Anaconda3\lib\site-packages\Cython\Build\IpythonMagic.py in cython(self, line, cell)
#     331
#     332         self._build_extension(extension, lib_dir, pgo_step_name='use' if args.pgo else None,
# --> 333                               quiet=args.quiet)
#     334
#     335         module = imp.load_dynamic(module_name, module_path)
#
# C:\Users\erics\Anaconda3\lib\site-packages\Cython\Build\IpythonMagic.py in _build_extension(self, extension, lib_dir, temp_dir, pgo_step_name, quiet)
#     441             if not quiet:
#     442                 old_threshold = distutils.log.set_threshold(distutils.log.DEBUG)
# --> 443             build_extension.run()
#     444         finally:
#     445             if not quiet and old_threshold is not None:
#
# C:\Users\erics\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     306                                      verbose=self.verbose,
#     307                                      dry_run=self.dry_run,
# --> 308                                      force=self.force)
#     309         customize_compiler(self.compiler)
#     310         # If we are cross-compiling, init the compiler now (if we are not
#
# C:\Users\erics\Anaconda3\lib\distutils\ccompiler.py in new_compiler(plat, compiler, verbose, dry_run, force)
#    1029     # with classes that expect verbose to be the first positional
#    1030     # argument.
# -> 1031     return klass(None, dry_run, force)
#    1032
#    1033
#
# C:\Users\erics\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     283     def __init__(self, verbose=0, dry_run=0, force=0):
#     284
# --> 285         CygwinCCompiler.__init__ (self, verbose, dry_run, force)
#     286
#     287         # ld_version >= "2.13" support -shared so use it instead of
#
# C:\Users\erics\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     127         # same as the rest of binutils ( also ld )
#     128         # dllwrap 2.10.90 is buggy
# --> 129         if self.ld_version >= "2.10.90":
#     130             self.linker_dll = "gcc"
#     131         else:
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'str'

# %%
from scipy.stats import multivariate_normal
def Multinorm_post_marginal_likelihood(mu_0, kappa_0, nu_0, Psi_0):
    """
    Returns a function that computes the marginal likelihood 
    for a Normal-inverse-Wishart model with specifies data and prior parameters.
    """
        
    def marginal_likelihood(data):
        
        n = data.shape[0]
        p = data.shape[1]
        xbar = data.mean(axis = 0)
    
        #update posterior parameters
        kappa_n = kappa_0 + n
        mu_n = (kappa_0 * mu_0 + n * xbar) / kappa_n
        nu_n = nu_0 + n
    
        if (n == 1):
            C = np.zeros((p, p))
        else:
            C = (n - 1) * np.cov(data.T)
        Psi_n = Psi_0 + C + ((n * kappa_0) / (kappa_n)) * np.dot((xbar - mu_0).reshape(-1, p).T, (xbar - mu_0).reshape(-1, p))
    
        return (1 / np.pi**(n * p / 2)) * (np.exp(multigammaln(nu_n / 2, p)) / np.exp(multigammaln(nu_0 / 2, p))) * (np.linalg.det(Psi_0)**(nu_0 / 2) / np.linalg.det(Psi_n)**(nu_n / 2)) * (kappa_0 / kappa_n)**(p / 2)

    return marginal_likelihood

# %%
import numpy as np
n = 10
y1 = np.random.multivariate_normal([0, 0], np.eye(2) * 0.1, n)
y2 = np.random.multivariate_normal([5, 0], np.eye(2) * 0.3, n)
y3 = np.random.multivariate_normal([0, 5], np.eye(2) * 0.5, n)
y4 = np.random.multivariate_normal([-5, 5], np.eye(2) * 0.7, n)
y5 = np.random.multivariate_normal([0, -5], np.eye(2) * 0.9, n)
data = np.vstack((y1, y2, y3, y4, y5))

likelihood = Multinorm_post_marginal_likelihood(mu_0 = np.zeros(2), kappa_0 = 1, nu_0 = 2 + 1, Psi_0 = np.eye(2))

# %%
clusters, rks = BHC_vanilla(data, likelihood, 1)
clust_n = next(x for x, val in enumerate(rks) if val < 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-640316116163> in <module>()
# ----> 1 clusters, rks = BHC_vanilla(data, likelihood, 1)
#       2 clust_n = next(x for x, val in enumerate(rks) if val < 0.5)
#
# NameError: name 'BHC_vanilla' is not defined

# %%
clust_n = data.shape[0] - next(x for x, val in enumerate(rks) if val < 0.5) + 1
clust_n
# Out:
# 4

# %%
import matplotlib.pyplot as plt

plt.scatter(data[:, 0], data[:, 1], c = clusters[-clust_n], s = 50)
plt.show()

# %% [markdown]
# Test

# %%
import numpy as np
import itertools as it
from scipy.special import gamma
from scipy.special import multigammaln

def BHC_vanilla(data, likelihood, alpha):
    """`
    Bayesian hierarchical clustering algorithm, direct implementation from paper.
    
    Parameters
    ----------
    data : 2D numpy array
        Data with rows as observations and columns as variables.
    likelihood : function
        Function that returns the marginal likelihood of data in BHC model.
    alpha : float
        Concentration parameter in model.
        
    Returns
    -------
    T_record : list(list(int))
        Cluster structure in each iteration.
    rk_record : list(float)
        Merge probability (rk) in each iteration.
    """
    
    n = data.shape[0]
    p = data.shape[1]
    c = n
    D = dict((index, Node(obs.reshape(-1, p), alpha)) for index, obs in enumerate(data))
    T = list(range(n))
    T_record = list(T)
    rk_record = [1]
    
    while c > 1:
        max_rk = float('-Inf')
        node_merge = None
        left_merge = -1
        right_merge = -1
        
        for i, j in it.combinations(D.keys(), 2):
            Di = D[i]
            Dj = D[j]
            Dk = Node.merge_node(Di, Dj)
            
            likelihood_i = likelihood(Di.data)
            likelihood_j = likelihood(Dj.data)
            likelihood_k = likelihood(Dk.data)
            
            pi_k = Dk.pi_k

            rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)

            if rk > max_rk:
                max_rk = rk
                node_merge = Dk
                left_merge = i
                right_merge = j
        
        #delete merged nodes and store new node
        del D[right_merge]
        D[left_merge] = node_merge

        #store the current tree structure and value of rk
        for item_index, node_index in enumerate(T):
            if node_index == right_merge:
                T[item_index] = left_merge
        T_record.append(list(T))
        rk_record.append(max_rk)
        
        c -= 1
        
    return T_record, rk_record
        

class Node(object):
    """
    Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.
    
    Attributes
    ----------
    data : 2D numpy array
        Data with rows as observations and columns as variables.
    dk : float
        Some kind of number for computing probabilities
    pi_k : float
        For to compute merge probability
        
    Methods
    -------
    __init__(self, data, likelihood, alpha = 1)
        Instantiation operation.
    merge_node(cls, node1, node2, alpha = 1)
        Method that merges two Nodes into one new Node and return the new Node.
    """
    
    def __init__(self, data, alpha = 1, dk = 1, pi_k = 1):
        """
        Instantiation operation.
        
        Parameters
        ----------
        data : 2D numpy array
            Data with rows as observations and columns as variables.
        likelihood : function
            Function that returns the likelihood of data, sampling distribution in BHC model.
        alpha : float
            Concentration parameter in model.
        log_dk : float
            Cached probability variable. Do not define if the node is a leaf.
        log_pi : float
            Cached probability variable. Do not define if the node is a leaf.
        """
        
        #initialized according to paper
        self.data = data
        self.dk = dk
        self.pi_k = pi_k

    @classmethod
    def merge_node(cls, node1, node2, alpha = 1):
        """
        Merge two Nodes into one new Node and return the new Node.
        
        Parameters
        ----------
        node1 : Node
            First Node.
        node2 : Node
            Second Node.
        """

        data = np.vstack((node1.data, node2.data))

        nk = data.shape[0]
        dk = alpha * gamma(nk) + node1.dk * node2.dk
        pi_k = alpha * gamma(nk) / dk

        return cls(data, alpha, dk, pi_k)

# %%
# %timeit -r3 -n1 BHC_vanilla(data, likelihood, 1)
# Out:
# 1 loop, best of 3: 7.56 s per loop

# %%
# %%cython -a
#
# import numpy as np
# import itertools as it
# from scipy.special import gamma
# from scipy.special import multigammaln
# import cython
# cimport numpy as np
# from numpy.math cimport INFINITY
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def BHC_cython(data, likelihood, int alpha):
#     """
#     Bayesian hierarchical clustering algorithm, direct implementation from paper.
#
#     Parameters
#     ----------
#     data : 2D numpy array
#         Data with rows as observations and columns as variables.
#     likelihood : function
#         Function that returns the marginal likelihood of data in BHC model.
#     alpha : float
#         Concentration parameter in model.
#
#     Returns
#     -------
#     T_record : list(list(int))
#         Cluster structure in each iteration.
#     rk_record : list(float)
#         Merge probability (rk) in each iteration.
#     """
#
#     #Using Cython
#
#     cdef int i, j
#     cdef float max_rk
#     cdef int left_merge, right_merge
#     cdef double likelihood_i, likelihood_j, likelihood_k
#     cdef double pi_k, rk
#
#     cdef int n = data.shape[0]
#     cdef int p = data.shape[1]
#     cdef int c = n
#     D = dict((index, Node(obs.reshape(-1, p), alpha)) for index, obs in enumerate(data))
#     cdef np.ndarray[dtype = long, ndim = 1] T = np.array(range(n))
#     cdef list T_record = list(T)
#     cdef list rk_record = [1]
#
#     while c > 1:
#
#         max_rk = -INFINITY
#         node_merge = None
#         left_merge = -1
#         right_merge = -1
#
#         for i, j in it.combinations(D.keys(), 2):
#             Di = D[i]
#             Dj = D[j]
#             Dk = Node.merge_node(Di, Dj)
#
#             likelihood_i = likelihood(Di.data)
#             likelihood_j = likelihood(Dj.data)
#             likelihood_k = likelihood(Dk.data)
#
#             pi_k = Dk.pi_k
#
#             rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)
#
#             if rk > max_rk:
#                 max_rk = rk
#                 node_merge = Dk
#                 left_merge = i
#                 right_merge = j
#
#         #delete merged nodes and store new node
#         del D[right_merge]
#         D[left_merge] = node_merge
#
#         #store the current tree structure and value of rk
#         for item_index, node_index in enumerate(T):
#             if node_index == right_merge:
#                 T[item_index] = left_merge
#         T_record.append(list(T))
#         rk_record.append(max_rk)
#
#         c -= 1
#
#     return T_record, rk_record
#
#
# cdef class Node(object):
#     """
#     Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.
#
#     Attributes
#     ----------
#     data : 2D numpy array
#         Data with rows as observations and columns as variables.
#     dk : float
#         Some kind of number for computing probabilities
#     pi_k : float
#         For to compute merge probability
#
#     Methods
#     -------
#     __init__(self, data, likelihood, alpha = 1)
#         Instantiation operation.
#     merge_node(cls, node1, node2, alpha = 1)
#         Method that merges two Nodes into one new Node and return the new Node.
#     """
#
#
#     cdef int alpha
#     cdef double dk, pi_k
#
#
#     def __init__(self, np.ndarray[dtype = double, ndim = 2] data, int alpha = 1, double dk = 1, double pi_k = 1):
#         """
#         Instantiation operation.
#
#         Parameters
#         ----------
#         data : 2D numpy array
#             Data with rows as observations and columns as variables.
#         likelihood : function
#             Function that returns the likelihood of data, sampling distribution in BHC model.
#         alpha : float
#             Concentration parameter in model.
#         log_dk : float
#             Cached probability variable. Do not define if the node is a leaf.
#         log_pi : float
#             Cached probability variable. Do not define if the node is a leaf.
#         """
#
#         #initialized according to paper
#         self.data = data
#         self.dk = dk
#         self.pi_k = pi_k
#
#
#     @classmethod
#     def merge_node(cls, node1, node2, int alpha = 1):
#         """
#         Merge two Nodes into one new Node and return the new Node.
#
#         Parameters
#         ----------
#         node1 : Node
#             First Node.
#         node2 : Node
#             Second Node.
#         """
#
#         cdef np.ndarray[dtype = double, ndim = 2] data = np.vstack((node1.data, node2.data))
#
#         cdef int nk = data.shape[0]
#         dk = alpha * gamma(nk) + node1.dk * node2.dk
#         pi_k = alpha * gamma(nk) / dk
#
#         return cls(data, alpha, dk, pi_k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-eb8db1c4f060> in <module>()
# ----> 1 get_ipython().run_cell_magic('cython', '-a', '\nimport numpy as np\nimport itertools as it\nfrom scipy.special import gamma\nfrom scipy.special import multigammaln\nimport cython\ncimport numpy as np\nfrom numpy.math cimport INFINITY\n\n@cython.boundscheck(False)\n@cython.wraparound(False)\ndef BHC_cython(data, likelihood, int alpha):\n    """\n    Bayesian hierarchical clustering algorithm, direct implementation from paper.\n    \n    Parameters\n    ----------\n    data : 2D numpy array\n        Data with rows as observations and columns as variables.\n    likelihood : function\n        Function that returns the marginal likelihood of data in BHC model.\n    alpha : float\n        Concentration parameter in model.\n        \n    Returns\n    -------\n    T_record : list(list(int))\n        Cluster structure in each iteration.\n    rk_record : list(float)\n        Merge probability (rk) in each iteration.\n    """\n    \n    #Using Cython \n\n    cdef int i, j\n    cdef float max_rk\n    cdef int left_merge, right_merge\n    cdef double likelihood_i, likelihood_j, likelihood_k\n    cdef double pi_k, rk\n\n    cdef int n = data.shape[0]\n    cdef int p = data.shape[1]\n    cdef int c = n\n    D = dict((index, Node(obs.reshape(-1, p), alpha)) for index, obs in enumerate(data))\n    cdef np.ndarray[dtype = long, ndim = 1] T = np.array(range(n))\n    cdef list T_record = list(T)\n    cdef list rk_record = [1]\n    \n    while c > 1:\n        \n        max_rk = -INFINITY\n        node_merge = None\n        left_merge = -1\n        right_merge = -1\n        \n        for i, j in it.combinations(D.keys(), 2):\n            Di = D[i]\n            Dj = D[j]\n            Dk = Node.merge_node(Di, Dj)\n            \n            likelihood_i = likelihood(Di.data)\n            likelihood_j = likelihood(Dj.data)\n            likelihood_k = likelihood(Dk.data)\n            \n            pi_k = Dk.pi_k\n\n            rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)\n\n            if rk > max_rk:\n                max_rk = rk\n                node_merge = Dk\n                left_merge = i\n                right_merge = j\n        \n        #delete merged nodes and store new node\n        del D[right_merge]\n        D[left_merge] = node_merge\n\n        #store the current tree structure and value of rk\n        for item_index, node_index in enumerate(T):\n            if node_index == right_merge:\n                T[item_index] = left_merge\n        T_record.append(list(T))\n        rk_record.append(max_rk)\n        \n        c -= 1\n        \n    return T_record, rk_record\n        \n\ncdef class Node(object):\n    """\n    Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.\n    \n    Attributes\n    ----------\n    data : 2D numpy array\n        Data with rows as observations and columns as variables.\n    dk : float\n        Some kind of number for computing probabilities\n    pi_k : float\n        For to compute merge probability\n        \n    Methods\n    -------\n    __init__(self, data, likelihood, alpha = 1)\n        Instantiation operation.\n    merge_node(cls, node1, node2, alpha = 1)\n        Method that merges two Nodes into one new Node and return the new Node.\n    """\n    \n\n    cdef int alpha\n    cdef double dk, pi_k\n\n    \n    def __init__(self, np.ndarray[dtype = double, ndim = 2] data, int alpha = 1, double dk = 1, double pi_k = 1):\n        """\n        Instantiation operation.\n        \n        Parameters\n        ----------\n        data : 2D numpy array\n            Data with rows as observations and columns as variables.\n        likelihood : function\n            Function that returns the likelihood of data, sampling distribution in BHC model.\n        alpha : float\n            Concentration parameter in model.\n        log_dk : float\n            Cached probability variable. Do not define ...
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-125> in cython(self, line, cell)
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\erics\Anaconda3\lib\site-packages\Cython\Build\IpythonMagic.py in cython(self, line, cell)
#     289             build_extension.build_temp = os.path.dirname(pyx_file)
#     290             build_extension.build_lib  = lib_dir
# --> 291             build_extension.run()
#     292             self._code_cache[key] = module_name
#     293
#
# C:\Users\erics\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     306                                      verbose=self.verbose,
#     307                                      dry_run=self.dry_run,
# --> 308                                      force=self.force)
#     309         customize_compiler(self.compiler)
#     310         # If we are cross-compiling, init the compiler now (if we are not
#
# C:\Users\erics\Anaconda3\lib\distutils\ccompiler.py in new_compiler(plat, compiler, verbose, dry_run, force)
#    1029     # with classes that expect verbose to be the first positional
#    1030     # argument.
# -> 1031     return klass(None, dry_run, force)
#    1032
#    1033
#
# C:\Users\erics\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     283     def __init__(self, verbose=0, dry_run=0, force=0):
#     284
# --> 285         CygwinCCompiler.__init__ (self, verbose, dry_run, force)
#     286
#     287         # ld_version >= "2.13" support -shared so use it instead of
#
# C:\Users\erics\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     127         # same as the rest of binutils ( also ld )
#     128         # dllwrap 2.10.90 is buggy
# --> 129         if self.ld_version >= "2.10.90":
#     130             self.linker_dll = "gcc"
#     131         else:
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'str'

# %%
# %timeit -r3 -n1 BHC_cython(data, likelihood, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2c9a5f749f72> in <module>()
# ----> 1 get_ipython().magic('timeit -r3 -n1 BHC_cython(data, likelihood, 1)')
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in timeit(self, line, cell)
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell)
#    1052                     break
#    1053                 number *= 10
# -> 1054         all_runs = timer.repeat(repeat, number)
#    1055         best = min(all_runs) / number
#    1056
#
# C:\Users\erics\Anaconda3\lib\timeit.py in repeat(self, repeat, number)
#     204         r = []
#     205         for i in range(repeat):
# --> 206             t = self.timeit(number)
#     207             r.append(t)
#     208         return r
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# NameError: name 'BHC_cython' is not defined

# %% [markdown]
# JIT

# %%
import numpy as np
import itertools as it
from scipy.special import gamma
from scipy.special import multigammaln
import numba
from numba import njit

# %%
conda install -c numba numba
# Out:
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
# Collecting package metadata: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/minchel93/anaconda3
#
#   added / updated specs:
#     - numba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.6.14               |           py37_0         2.1 MB
#     ------------------------------------------------------------
#                                            Total:         2.1 MB
#
# The following packages will be UPDATED:
#
#   conda                                       4.6.11-py37_0 --> 4.6.14-py37_0
#
#
#
# Downloading and Extracting Packages
# conda-4.6.14         | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import itertools as it
from scipy.special import gamma
from scipy.special import multigammaln

def BHC_vanilla(data, likelihood, alpha):
    """
    Bayesian hierarchical clustering algorithm, direct implementation from paper.
    
    Parameters
    ----------
    data : 2D numpy array
        Data with rows as observations and columns as variables.
    likelihood : function
        Function that returns the marginal likelihood of data in BHC model.
    alpha : float
        Concentration parameter in model.
        
    Returns
    -------
    T_record : list(list(int))
        Cluster structure in each iteration.
    rk_record : list(float)
        Merge probability (rk) in each iteration.
    """
    
    n = data.shape[0]
    p = data.shape[1]
    c = n
    D = dict((index, Node(obs.reshape(-1, p), alpha)) for index, obs in enumerate(data))
    T = list(range(n))
    T_record = list(T)
    rk_record = [1]
    
    while c > 1:
        max_rk = float('-Inf')
        node_merge = None
        left_merge = -1
        right_merge = -1
        
        for i, j in it.combinations(D.keys(), 2):
            Di = D[i]
            Dj = D[j]
            Dk = Node.merge_node(Di, Dj)
            
            likelihood_i = likelihood(Di.data)
            likelihood_j = likelihood(Dj.data)
            likelihood_k = likelihood(Dk.data)
            
            pi_k = Dk.pi_k

            rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)

            if rk > max_rk:
                max_rk = rk
                node_merge = Dk
                left_merge = i
                right_merge = j
        
        #delete merged nodes and store new node
        del D[right_merge]
        D[left_merge] = node_merge

        #store the current tree structure and value of rk
        for item_index, node_index in enumerate(T):
            if node_index == right_merge:
                T[item_index] = left_merge
        T_record.append(list(T))
        rk_record.append(max_rk)
        
        c -= 1
        
    return T_record, rk_record
        

class Node(object):
    """
    Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.
    
    Attributes
    ----------
    data : 2D numpy array
        Data with rows as observations and columns as variables.
    dk : float
        Some kind of number for computing probabilities
    pi_k : float
        For to compute merge probability
        
    Methods
    -------
    __init__(self, data, likelihood, alpha = 1)
        Instantiation operation.
    merge_node(cls, node1, node2, alpha = 1)
        Method that merges two Nodes into one new Node and return the new Node.
    """
    
    def __init__(self, data, alpha = 1, dk = 1, pi_k = 1):
        """
        Instantiation operation.
        
        Parameters
        ----------
        data : 2D numpy array
            Data with rows as observations and columns as variables.
        likelihood : function
            Function that returns the likelihood of data, sampling distribution in BHC model.
        alpha : float
            Concentration parameter in model.
        log_dk : float
            Cached probability variable. Do not define if the node is a leaf.
        log_pi : float
            Cached probability variable. Do not define if the node is a leaf.
        """
        
        #initialized according to paper
        self.data = data
        self.dk = dk
        self.pi_k = pi_k

    @classmethod
    def merge_node(cls, node1, node2, alpha = 1):
        """
        Merge two Nodes into one new Node and return the new Node.
        
        Parameters
        ----------
        node1 : Node
            First Node.
        node2 : Node
            Second Node.
        """

        data = np.vstack((node1.data, node2.data))

        nk = data.shape[0]
        dk = alpha * gamma(nk) + node1.dk * node2.dk
        pi_k = alpha * gamma(nk) / dk

        return cls(data, alpha, dk, pi_k)

# %%
# %timeit -r3 -n1 BHC_vanilla(data, likelihood, 1)
# Out:
# 1 loop, best of 3: 7.55 s per loop

# %%
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
# %%cython -a
#
# import numpy as np
# import itertools as it
# from scipy.special import gamma
# from scipy.special import multigammaln
# import cython
# cimport numpy as np
# from numpy.math cimport INFINITY
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
#
# def BHC_cython(data, likelihood, int alpha):
#     """
#     Bayesian hierarchical clustering algorithm, direct implementation from paper.
#
#     Parameters
#     ----------
#     data : 2D numpy array
#         Data with rows as observations and columns as variables.
#     likelihood : function
#         Function that returns the marginal likelihood of data in BHC model.
#     alpha : float
#         Concentration parameter in model.
#
#     Returns
#     -------
#     T_record : list(list(int))
#         Cluster structure in each iteration.
#     rk_record : list(float)
#         Merge probability (rk) in each iteration.
#     """
#
#     cdef int n, p, c
#     cdef int i, j, i_posit, j_posit, merge_index1, merge_index2, merge_index1_posit, mege_index2_posit
#     cdef double max_rk
#     cdef double rk, dk, pi_k
#     cdef np.ndarray[dtype = long, ndim = 1] D_index
#     cdef double likelihood_i, likelihood_j, likelihood_k
#
#     n = data.shape[0]
#     p = data.shape[1]
#     c = n
#     D_index = np.array(range(n))
#     D_Node = np.array(list(Node(obs.reshape(-1, p), alpha) for obs in data))
#
#     T = list(range(n))
#     T_record = list(T)
#     rk_record = [1]
#
#     while c > 1:
#         max_rk = -INFINITY
#         node_merge = None
#         left_merge = -1
#         right_merge = -1
#
#         for i, j in it.combinations(D_index, 2):
#             i_posit = np.where(D_index == i)[0][0]
#             j_posit = np.where(D_index == j)[0][0]
#             Di = D_Node[i_posit]
#             Dj = D_Node[j_posit]
#             Dk = Node.merge_node(Di, Dj)
#
#             likelihood_i = likelihood(Di.data)
#             likelihood_j = likelihood(Dj.data)
#             likelihood_k = likelihood(Dk.data)
#
#             pi_k = Dk.pi_k
#
#             rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)
#
#             if rk > max_rk:
#                 max_rk = rk
#                 node_merge = Dk
#                 merge_index1_posit = i_posit
#                 merge_index2_posit = j_posit
#                 merge_index1 = i
#                 merge_index2 = j
#
#         #delete merged nodes and store new node
#         D_index = np.delete(D_index, merge_index2_posit)
#         D_Node = np.delete(D_Node, merge_index2_posit)
#         D_Node[merge_index1_posit] = node_merge
#
#         #store the current tree structure and value of rk
#         for item_index, node_index in enumerate(T):
#             if node_index == merge_index2:
#                 T[item_index] = merge_index1
#         T_record.append(list(T))
#         rk_record.append(max_rk)
#
#         c -= 1
#
#     return T_record, rk_record
#
#
# class Node(object):
#     """
#     Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.
#
#     Attributes
#     ----------
#     data : 2D numpy array
#         Data with rows as observations and columns as variables.
#     dk : float
#         Some kind of number for computing probabilities
#     pi_k : float
#         For to compute merge probability
#
#     Methods
#     -------
#     __init__(self, data, likelihood, alpha = 1)
#         Instantiation operation.
#     merge_node(cls, node1, node2, alpha = 1)
#         Method that merges two Nodes into one new Node and return the new Node.
#     """
#
#
#     def __init__(self, np.ndarray[dtype = double, ndim = 2] data, double alpha = 1, double dk = 1, double pi_k = 1):
#         """
#         Instantiation operation.
#
#         Parameters
#         ----------
#         data : 2D numpy array
#             Data with rows as observations and columns as variables.
#         likelihood : function
#             Function that returns the likelihood of data, sampling distribution in BHC model.
#         alpha : float
#             Concentration parameter in model.
#         log_dk : float
#             Cached probability variable. Do not define if the node is a leaf.
#         log_pi : float
#             Cached probability variable. Do not define if the node is a leaf.
#         """
#
#         #initialized according to paper
#         self.data = data
#         self.dk = dk
#         self.pi_k = pi_k
#
#     @classmethod
#     def merge_node(cls, node1, node2, double alpha = 1):
#         """
#         Merge two Nodes into one new Node and return the new Node.
#
#         Parameters
#         ----------
#         node1 : Node
#             First Node.
#         node2 : Node
#             Second Node.
#         """
#
#         cdef np.ndarray[dtype = double, ndim = 2] data
#         cdef int nk
#
#         data = np.vstack((node1.data, node2.data))
#
#         nk = data.shape[0]
#         dk = alpha * gamma(nk) + node1.dk * node2.dk
#         pi_k = alpha * gamma(nk) / dk
#
#         return cls(data, alpha, dk, pi_k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8a8b3df5a898> in <module>()
# ----> 1 get_ipython().run_cell_magic('cython', '-a', '\nimport numpy as np\nimport itertools as it\nfrom scipy.special import gamma\nfrom scipy.special import multigammaln\nimport cython\ncimport numpy as np\nfrom numpy.math cimport INFINITY\n\n@cython.boundscheck(False)\n@cython.wraparound(False)\n\ndef BHC_cython(data, likelihood, int alpha):\n    """\n    Bayesian hierarchical clustering algorithm, direct implementation from paper.\n    \n    Parameters\n    ----------\n    data : 2D numpy array\n        Data with rows as observations and columns as variables.\n    likelihood : function\n        Function that returns the marginal likelihood of data in BHC model.\n    alpha : float\n        Concentration parameter in model.\n        \n    Returns\n    -------\n    T_record : list(list(int))\n        Cluster structure in each iteration.\n    rk_record : list(float)\n        Merge probability (rk) in each iteration.\n    """\n    \n    cdef int n, p, c\n    cdef int i, j, i_posit, j_posit, merge_index1, merge_index2, merge_index1_posit, mege_index2_posit\n    cdef double max_rk\n    cdef double rk, dk, pi_k\n    cdef np.ndarray[dtype = long, ndim = 1] D_index\n    cdef double likelihood_i, likelihood_j, likelihood_k\n    \n    n = data.shape[0]\n    p = data.shape[1]\n    c = n\n    D_index = np.array(range(n))\n    D_Node = np.array(list(Node(obs.reshape(-1, p), alpha) for obs in data))\n    \n    T = list(range(n))\n    T_record = list(T)\n    rk_record = [1]\n    \n    while c > 1:\n        max_rk = -INFINITY\n        node_merge = None\n        left_merge = -1\n        right_merge = -1\n        \n        for i, j in it.combinations(D_index, 2):\n            i_posit = np.where(D_index == i)[0][0]\n            j_posit = np.where(D_index == j)[0][0]\n            Di = D_Node[i_posit]\n            Dj = D_Node[j_posit]\n            Dk = Node.merge_node(Di, Dj)\n            \n            likelihood_i = likelihood(Di.data)\n            likelihood_j = likelihood(Dj.data)\n            likelihood_k = likelihood(Dk.data)\n            \n            pi_k = Dk.pi_k\n\n            rk = (pi_k * likelihood_k) / (pi_k * likelihood_k + (1 - pi_k) * likelihood_i * likelihood_j)\n\n            if rk > max_rk:\n                max_rk = rk\n                node_merge = Dk\n                merge_index1_posit = i_posit\n                merge_index2_posit = j_posit\n                merge_index1 = i\n                merge_index2 = j\n        \n        #delete merged nodes and store new node\n        D_index = np.delete(D_index, merge_index2_posit)\n        D_Node = np.delete(D_Node, merge_index2_posit)\n        D_Node[merge_index1_posit] = node_merge\n\n        #store the current tree structure and value of rk\n        for item_index, node_index in enumerate(T):\n            if node_index == merge_index2:\n                T[item_index] = merge_index1\n        T_record.append(list(T))\n        rk_record.append(max_rk)\n        \n        c -= 1\n        \n    return T_record, rk_record\n        \n\nclass Node(object):\n    """\n    Node class used in Bayesian hierarchical clustering algorithm. Main purpose is to store values of dk and pi_k for each node.\n    \n    Attributes\n    ----------\n    data : 2D numpy array\n        Data with rows as observations and columns as variables.\n    dk : float\n        Some kind of number for computing probabilities\n    pi_k : float\n        For to compute merge probability\n        \n    Methods\n    -------\n    __init__(self, data, likelihood, alpha = 1)\n        Instantiation operation.\n    merge_node(cls, node1, node2, alpha = 1)\n        Method that merges two Nodes into one new Node and return the new Node.\n    """\n\n    \n    def __init__(self, np.ndarray[dtype = double, ndim = 2] data, double alpha = 1, double dk = 1, double pi_k = 1):\n        """\n        Instantiation operation.\n        \n        Parameters\n        ----------\n        data : 2D numpy array\n            Data with rows as observatio ...
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-125> in cython(self, line, cell)
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\erics\Anaconda3\lib\site-packages\Cython\Build\IpythonMagic.py in cython(self, line, cell)
#     331
#     332         self._build_extension(extension, lib_dir, pgo_step_name='use' if args.pgo else None,
# --> 333                               quiet=args.quiet)
#     334
#     335         module = imp.load_dynamic(module_name, module_path)
#
# C:\Users\erics\Anaconda3\lib\site-packages\Cython\Build\IpythonMagic.py in _build_extension(self, extension, lib_dir, temp_dir, pgo_step_name, quiet)
#     441             if not quiet:
#     442                 old_threshold = distutils.log.set_threshold(distutils.log.DEBUG)
# --> 443             build_extension.run()
#     444         finally:
#     445             if not quiet and old_threshold is not None:
#
# C:\Users\erics\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     306                                      verbose=self.verbose,
#     307                                      dry_run=self.dry_run,
# --> 308                                      force=self.force)
#     309         customize_compiler(self.compiler)
#     310         # If we are cross-compiling, init the compiler now (if we are not
#
# C:\Users\erics\Anaconda3\lib\distutils\ccompiler.py in new_compiler(plat, compiler, verbose, dry_run, force)
#    1029     # with classes that expect verbose to be the first positional
#    1030     # argument.
# -> 1031     return klass(None, dry_run, force)
#    1032
#    1033
#
# C:\Users\erics\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     283     def __init__(self, verbose=0, dry_run=0, force=0):
#     284
# --> 285         CygwinCCompiler.__init__ (self, verbose, dry_run, force)
#     286
#     287         # ld_version >= "2.13" support -shared so use it instead of
#
# C:\Users\erics\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     127         # same as the rest of binutils ( also ld )
#     128         # dllwrap 2.10.90 is buggy
# --> 129         if self.ld_version >= "2.10.90":
#     130             self.linker_dll = "gcc"
#     131         else:
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'str'

# %%
# %timeit -r3 -n1 BHC_cython(data, likelihood, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2c9a5f749f72> in <module>()
# ----> 1 get_ipython().magic('timeit -r3 -n1 BHC_cython(data, likelihood, 1)')
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in timeit(self, line, cell)
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell)
#    1052                     break
#    1053                 number *= 10
# -> 1054         all_runs = timer.repeat(repeat, number)
#    1055         best = min(all_runs) / number
#    1056
#
# C:\Users\erics\Anaconda3\lib\timeit.py in repeat(self, repeat, number)
#     204         r = []
#     205         for i in range(repeat):
# --> 206             t = self.timeit(number)
#     207             r.append(t)
#     208         return r
#
# C:\Users\erics\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# NameError: name 'BHC_cython' is not defined

# %%
def aloop(n = 30):
    a = 0
    for i in range(n):
        a = a + 1

# %%
# %timeit -r3 -n3 aloop(10000)
# Out:
# 3 loops, best of 3: 526 µs per loop
